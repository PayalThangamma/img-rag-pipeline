# %% [markdown]
# # Notebook for Generating Captions
#
# This notebook is used to generate artificial captions and create a synthetic dataset which paraphrases upon the captions in the pixel_prose dataset.

# %%
import pandas as pd
import numpy as np
import os
import json
from json import JSONDecodeError
import csv
import warnings
import os
import re


from dotenv import load_dotenv
from openai import OpenAI, RateLimitError

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
df = pd.read_csv("pixel_prose.csv")

# %%
df["original_caption"]
# Out:
# 0      Car riding on wet street. Car driving on wet c...
# 1                             Water Coming Out Of A Pipe
# 2      MARCH 2009 ''It's sad that a boy and girl can ...
# 3             Humpback Whale tail in the Bay of Banderas
# 4      The gaming Team logo of team DUO Team Logo, My...
#                              ...
# 494    The extended body on the this fly creates a mo...
# 495    Vector illustration of flowers in the shape of...
# 496    Winter snow storm in Boston's Public Garden .....
# 497    Close-up of business plan with people working ...
# 498    All smiles, <PERSON> poses for the lens of pho...
# Name: original_caption, Length: 499, dtype: object

# %%
df.index[0]
# Out:
# 0

# %%
df["vlm_caption"][1]
# Out:
# ' This image displays: A large rusty pipe with a white ring near the bottom. Water is gushing out of the pipe into a murky body of water below. The pipe is attached to a large hopper or funnel that is painted white and has some rust. The hopper is mostly obscured by a metal fence with square holes in it. There is a single plant growing next to the fence, with bright green leaves. The background is a blur of more metal fencing and concrete. The image is a photograph that has been taken from a low angle so that the water seems to be gushing towards the viewer.'

# %%
all_short_captions = []
for idx in df.index:
    all_short_captions.append({idx: df["original_caption"][idx]})

# %%
df
# Out:
#      Unnamed: 0                                                uid  \
# 0             1  c9d31cce99482e8da13f6a868e2472c3bc3ea05a874e5b...
# 1             2  f3a6ad643814199a98f872229758b8e735773c1803e2f1...
# 2             3  3b03f5e3a32499281dbeebb9a0e1d3dfe883bc7b72e2eb...
# 3             4  9f3b5395744728e68b85083c0411c3b4139214f1258bf7...
# 4             5  e3c7435ce411fea5656c792355a3811163da286673f8e5...
# ..          ...                                                ...
# 494         594  34aa54a20f7a91d93af20ac4183e1fe8ef19d57284c353...
# 495         595  4d315306896f25b3fc3b1721a9e8a265b70818b5d22695...
# 496         596  7bdc3ead9988c533e52650eb9f374860b57b452b208e74...
# 497         598  77fe9e8070fe07894f8deb74cc64cfb3afa72829b2f5c9...
# 498         599  2dfcc5a97e1c4bc1cb26b320c53ea2e8421966b206f3b2...
#
#                                                    url      key   status  \
# 0    https://thumbs.dreamstime.com/b/car-riding-wet...  7740001  success
# 1    https://images.pexels.com/photos/770224/pexels...  7740009  success
# 2    https://filmfare.wwmindia.com/content/2017/jul...  7740010  success
# 3    https://southernersays.com/wp-content/uploads/...  7740000  success
# 4    https://i.pinimg.com/originals/9a/f5/a6/9af5a6...  7740035  success
# ..                                                 ...      ...      ...
# 494  https://images.squarespace-cdn.com/content/v1/...  7740813  success
# 495  https://image.shutterstock.com/z/stock-vector-...  7740791  success
# 496  https://www.boston-discovery-guide.com/image-f...  7740821  success
# 497  https://image.freepik.com/free-photo/close-up-...  7740793  success
# 498  https://www.thefashionisto.com/wp-content/uplo...  7740815  success
#
#                                       original_caption          vlm_model  \
# 0    Car riding on wet street. Car driving on wet c...  gemini-pro-vision
# 1                           Water Coming Out Of A Pipe  gemini-pro-vision
# 2    MARCH 2009 ''It's sad that a boy and girl can ...  gemini-pro-vision
# 3           Humpback Whale tail in the Bay of Banderas  gemini-pro-vision
# 4    The gaming Team logo of team DUO Team Logo, My...  gemini-pro-vision
# ..                                                 ...                ...
# 494  The extended body on the this fly creates a mo...  gemini-pro-vision
# 495  Vector illustration of flowers in the shape of...  gemini-pro-vision
# 496  Winter snow storm in Boston's Public Garden .....  gemini-pro-vision
# 497  Close-up of business plan with people working ...  gemini-pro-vision
# 498  All smiles, <PERSON> poses for the lens of pho...  gemini-pro-vision
#
#                                            vlm_caption  toxicity  \
# 0     This image displays:\n\nA black car driving t...  0.005905
# 1     This image displays: A large rusty pipe with ...  0.002487
# 2     This image displays: three pictures of Katrin...  0.001743
# 3     This image displays:\nA photograph of a whale...  0.006152
# 4     This image displays:\n\nText that reads "20% ...  0.007788
# ..                                                 ...       ...
# 494   This image displays: A close-up photograph of...  0.000551
# 495   This image displays:\n\nA black crescent moon...  0.007320
# 496   This image displays: Two women walking away f...  0.002525
# 497   This image displays:\n\nIn the foreground of ...  0.000409
# 498   This image displays:\n\nThis image displays a...  0.003489
#
#      severe_toxicity  ...  width  height  original_width  original_height  \
# 0           0.000017  ...    800     534             800              534
# 1           0.000007  ...    500     750             500              750
# 2           0.000003  ...    600     450             600              450
# 3           0.000024  ...   1024     662            1024              662
# 4           0.000023  ...   1820    1024            1920             1080
# ..               ...  ...    ...     ...             ...              ...
# 494         0.000001  ...   1000     750            1000              750
# 495         0.000019  ...   1024    1092            1500             1600
# 496         0.000017  ...    800     440             800              440
# 497         0.000001  ...    626     433             626              433
# 498         0.000018  ...    800     960             800              960
#
#                                                   exif  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 494                                                 {}
# 495  {"Image Orientation": "Horizontal (normal)", "...
# 496  {"Image Make": "Panasonic", "Image Model": "DM...
# 497                                                 {}
# 498  {"Image PhotometricInterpretation": "2", "Imag...
#
#                                                 sha256  image_id  author  \
# 0    c9d31cce99482e8da13f6a868e2472c3bc3ea05a874e5b...       NaN     NaN
# 1    f3a6ad643814199a98f872229758b8e735773c1803e2f1...       NaN     NaN
# 2    3b03f5e3a32499281dbeebb9a0e1d3dfe883bc7b72e2eb...       NaN     NaN
# 3    9f3b5395744728e68b85083c0411c3b4139214f1258bf7...       NaN     NaN
# 4    e3c7435ce411fea5656c792355a3811163da286673f8e5...       NaN     NaN
# ..                                                 ...       ...     ...
# 494  34aa54a20f7a91d93af20ac4183e1fe8ef19d57284c353...       NaN     NaN
# 495  4d315306896f25b3fc3b1721a9e8a265b70818b5d22695...       NaN     NaN
# 496  7bdc3ead9988c533e52650eb9f374860b57b452b208e74...       NaN     NaN
# 497  77fe9e8070fe07894f8deb74cc64cfb3afa72829b2f5c9...       NaN     NaN
# 498  2dfcc5a97e1c4bc1cb26b320c53ea2e8421966b206f3b2...       NaN     NaN
#
#      subreddit  score
# 0           -1     -1
# 1           -1     -1
# 2           -1     -1
# 3           -1     -1
# 4           -1     -1
# ..         ...    ...
# 494         -1     -1
# 495         -1     -1
# 496         -1     -1
# 497         -1     -1
# 498         -1     -1
#
# [499 rows x 29 columns]

# %%
df.loc[[0,1,2,3,4]]["url"]
# Out:
# 0    https://thumbs.dreamstime.com/b/car-riding-wet...
# 1    https://images.pexels.com/photos/770224/pexels...
# 2    https://filmfare.wwmindia.com/content/2017/jul...
# 3    https://southernersays.com/wp-content/uploads/...
# 4    https://i.pinimg.com/originals/9a/f5/a6/9af5a6...
# Name: url, dtype: object

# %%
def initialize_csv(file_path):
    """
    initialises a CSV 

    Args:
        file_path: a string which will be the location of the CSV
    Return:
        None
    """
    with open(file_path, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["id", "img_url", "original_caption", "paraphrased_caption"])


def append_to_csv(file_path, rows):
    """
    Adds multiple rows to the CSV
    Args:
        file_path: a string which will be the location of the CSV
        rows: a list containing tuples where each tuple will be a row
    """
    with open(file_path, mode='a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerows(rows)



def create_artificial_captions(captions):
    """
    Generates artificial captions using OpenAIs GPT

    Args:
        captions: a list of objects where each object has a key (id) and value (caption)
    Return:
        output_dict: A dictionary where key is the id and value is the paraphrased caption
    """
    print(captions)
    # define model and temperature. A higher temperature is chosen for variability in the captions so that it is not the same caption just reworded
    MODEL = "gpt-4o-mini"
    TEMPERATURE = 1.0

    prompt = f"""
        You are a helpful assistant that rewrites short image captions. You are generating captions to assess how well image retrieval can go with varying captions. Paraphrase the following captions. You may deviate slightly from the text to make the output caption slightly more different. You may omit less relevant details such as names of places or people in some captions. DO NOT ADD ANYTHING MORE THAN A REPHRASED CAPTION. Do NOT reorder the generated captions. Return each generated caption in the same order that they were passed in. Respond only with a JSON object. Use double quotes for all keys and values where the key is the id and the value is the rephrased caption. The id is given as part of each caption. You are to make this same id the key in your output. It is imperitive that you do not reorder, or skip over the captions. \n\n\n

        {captions}
        """
    
    try:

        # send a request
        response = client.chat.completions.create(
            model=MODEL,
            temperature=TEMPERATURE,
            messages=[
                {"role": "system", "content": "You rephrase lists of short captions without changing meaning."},
                {"role": "user", "content": prompt}
            ]
        )

        # extract response and to generated_original_captions list
        raw_output = response.choices[0].message.content.strip()
        print(f"Raw output is {raw_output}")
        if raw_output.startswith("```"):
            lines = raw_output.splitlines()
            # remove the first and last lines (```json and ```) as it causes errors otherwise
            raw_output = "\n".join(lines[1:-1])
        output_dict = json.loads(raw_output)

        return output_dict

    
    except RateLimitError as e:
        warnings.warn(e)
    except JSONDecodeError as e:
        warnings.warn(e)

def generate_captions(df, col_name, path_to_save, num_partitions):
    """
    Generates artificial captions by preprocessing dataframe, extracting column and calling create_artificial_captions

    Args:
        df: A dataframe containing the captions to paraphrase
        col_name: A string referencing the column name of the captions (should be original_caption or vlm_model)
        path_to_save: a string which defines where to save the rows containing the paraphrased captions to
        num_partitions: An integer used to control number of partitions to split dataframe into. This is the number of requests made to the API and is needed so that the API will not make too many mistakes after taking the whole dataframe in.

    Return:
        None

    Note: We have found that increasing num_partitions reduces risk of error, likely because there is less to process per call
    """
    
    # create a list of dictionaries where key is id and value is the caption to convert
    all_short_captions = []
    for idx in df.index:
        all_short_captions.append({idx: df[col_name][idx]})

    # process x amount of captions first, save, then add x more and so on
    num_captions_per_batch = (len(all_short_captions) // num_partitions) + 1
    print(num_captions_per_batch)

    # we want to process the first x captions, and save it to a csv
    for partition in range(num_partitions):
        output_dict = {}
        if partition == num_partitions - 1:
            # take all remaining
            output_dict = create_artificial_captions(all_short_captions[partition * num_captions_per_batch: ])
        else: 
            # take exactly a batch worth of captions
            output_dict = create_artificial_captions(all_short_captions[partition * num_captions_per_batch: (partition+1)*num_captions_per_batch])
        print("Output dict is ", output_dict)

        # now save it to the csv by making a valid row
        # convert the string ids into int
        ids = list(map(int, output_dict.keys()))
        # make sure that the captions are in the correct order
        captions = [output_dict[str(i)] for i in ids]
        img_urls = df.loc[ids]["url"].tolist()
        og_captions = df.loc[ids][col_name].tolist()
        rows = list(zip(ids, img_urls, og_captions, captions))

        # add to csv
        append_to_csv(path_to_save, rows)

# %% [markdown]
# ## Generating Short Captions

# %%
FILE_PATH = "./short_generated_captions.csv"

initialize_csv(FILE_PATH)

# %%
generate_captions(df, "original_caption", FILE_PATH, 50)
# Out:
# 10
# [{0: 'Car riding on wet street. Car driving on wet city street during a downpour stock photography'}, {1: 'Water Coming Out Of A Pipe'}, {2: "MARCH 2009 ''It's sad that a boy and girl can never be friends out here. First they linked me with <PERSON>, it's <PERSON>'s turn now.'' Katrina: It's true. They're still doing it. AUGUST 2009 '' <PERSON>, <PERSON>"}, {3: 'Humpback Whale tail in the Bay of Banderas'}, {4: 'The gaming Team logo of team DUO Team Logo, My Design, Gaming, Logos, Game, Videogames, Logo, Games'}, {5: 'Tea, chilies, and takeaway: what food choices reveal about British Muslim identity'}, {6: 'The Bath Co. Camberley satin grey vanity unit with basin White Vanity Unit, Basin Vanity Unit, Gray Vanity, Bathroom Vanity Units, Vanity Sink, Bathroom Basin, Family Bathroom, Downstairs Bathroom, Small Bathroom'}, {7: 'Celebs attend the launch of a style store'}, {8: 'Europe always amazes me on how well their architecture withstands the test of time. Croatia was no exception.'}, {9: 'The Development of the Court'}]
# Raw output is ```json
# {
#     "0": "Vehicle driving on a rainy city street.",
#     "1": "Water spilling from a pipe.",
#     "2": "MARCH 2009 'It's unfortunate that a boy and girl can't just be friends here. They first connected me with <PERSON>, now it’s <PERSON>'s turn.' Katrina: 'It's true. They're still at it.' AUGUST 2009 '<PERSON>, <PERSON>'",
#     "3": "Humpback whale fin in the Banderas Bay.",
#     "4": "DUO Team logo design featuring gaming themes.",
#     "5": "Tea, chilies, and takeout: insights into British Muslim identity through food choices.",
#     "6": "The Bath Co. Camberley satin grey vanity unit complete with basin.",
#     "7": "Celebrities grace the opening of a fashion store.",
#     "8": "I'm always impressed by how Europe's architecture endures over time. Croatia is no exception.",
#     "9": "The Evolution of the Court"
# }
# ```
# Output dict is  {'0': 'Vehicle driving on a rainy city street.', '1': 'Water spilling from a pipe.', '2': "MARCH 2009 'It's unfortunate that a boy and girl can't just be friends here. They first connected me with <PERSON>, now it’s <PERSON>'s turn.' Katrina: 'It's true. They're still at it.' AUGUST 2009 '<PERSON>, <PERSON>'", '3': 'Humpback whale fin in the Banderas Bay.', '4': 'DUO Team logo design featuring gaming themes.', '5': 'Tea, chilies, and takeout: insights into British Muslim identity through food choices.', '6': 'The Bath Co. Camberley satin grey vanity unit complete with basin.', '7': 'Celebrities grace the opening of a fashion store.', '8': "I'm always impressed by how Europe's architecture endures over time. Croatia is no exception.", '9': 'The Evolution of the Court'}
# [{10: "Skyscrapers in which businesses lead the country's economy."}, {11: "A night view of San Francisco's Chinatown in the 1950's. The streets are crowded with traffic and neon signs light up the night. Photo: Curt Teich Postcard Archives, Getty Images"}, {12: 'Restaurant exterior, guests sitting at the bar'}, {13: "This Ironstone pottery dinner plate was made by the <PERSON>'s factory at Lane Delph, Staffordshire, England and is decorated in the Chinese Scroll Pattern, fully stamped and dating to the earliest period of <PERSON>'s Ironstone production, circa"}, {14: 'Waving flag of Vietnam made of text symbols on a computer screen. Conceptual 3D rendering. Waving flag made of symbols on a computer screen stock illustration'}, {15: 'Teal Ballerinas for The Teal Recovery Charity Event'}, {16: "Balloon Mantle for for the Prophet <PERSON>'s Birthday Celebration"}, {17: 'A modern drinks trolley with a lower shelf, crafted from acrylic and glass with a stainless steel frame and wheels. Acrylic Furniture, Glass Furniture, Table Furniture, Lucite Furniture, Bar Trolley, Drinks Trolley, Bar Carts, <PERSON>, Hostess Trolley'}, {18: 'Wallpapers dog, chic, the cavalier king <PERSON>'}, {19: 'No jump sign vector design for advertising in luxury hotel, resort'}]
# Raw output is ```json
# {
#     "10": "Skyscrapers that drive the nation's economy.",
#     "11": "A nighttime scene of Chinatown in San Francisco during the 1950s, bustling with traffic and illuminated by neon signs. Photo: Curt Teich Postcard Archives, Getty Images",
#     "12": "Exterior of a restaurant with patrons seated at the bar.",
#     "13": "This dinner plate made of Ironstone pottery originates from the factory in Lane Delph, Staffordshire, England, featuring the Chinese Scroll Pattern, fully stamped and dating back to early production in that factory.",
#     "14": "Computer-generated waving flag of Vietnam created from text symbols. Conceptual 3D rendering.",
#     "15": "Teal Ballerinas for The Teal Recovery Charity Event.",
#     "16": "Decorative Balloon Mantle for the Prophet's Birthday Celebration.",
#     "17": "A contemporary drinks trolley featuring an acrylic and glass design with a stainless steel frame and wheels. Includes various types of furniture such as acrylic and glass.",
#     "18": "Chic wallpaper featuring a Cavalier King Charles spaniel.",
#     "19": "Vector design of a no-jump sign for luxury hotel and resort advertising."
# }
# ```
# Output dict is  {'10': "Skyscrapers that drive the nation's economy.", '11': 'A nighttime scene of Chinatown in San Francisco during the 1950s, bustling with traffic and illuminated by neon signs. Photo: Curt Teich Postcard Archives, Getty Images', '12': 'Exterior of a restaurant with patrons seated at the bar.', '13': 'This dinner plate made of Ironstone pottery originates from the factory in Lane Delph, Staffordshire, England, featuring the Chinese Scroll Pattern, fully stamped and dating back to early production in that factory.', '14': 'Computer-generated waving flag of Vietnam created from text symbols. Conceptual 3D rendering.', '15': 'Teal Ballerinas for The Teal Recovery Charity Event.', '16': "Decorative Balloon Mantle for the Prophet's Birthday Celebration.", '17': 'A contemporary drinks trolley featuring an acrylic and glass design with a stainless steel frame and wheels. Includes various types of furniture such as acrylic and glass.', '18': 'Chic wallpaper featuring a Cavalier King Charles spaniel.', '19': 'Vector design of a no-jump sign for luxury hotel and resort advertising.'}
# [{20: 'Natural Light Weathered Burford Walling - This light yellow reconstituted stone walling with grey highlights has a tumbled surface & is available in 3 sizes. Concrete Paving, Paving Stones, Patio Slabs, Modern Garden Design, Wall Cladding, Garden Stones, Grey Walls, Garden Projects, Natural Light'}, {21: 'The Franklin Inn functions as a social gathering for many locals, serving good food and a good time. ( <PERSON>/Huron Daily Tribune)'}, {22: 'The rocks looked totally different during the very short period of as close to sunshine as I got that morning.'}, {23: '<PERSON> - Churning of the Cosmic Ocean ca Ravi Varma Press Lithograph. Shiva Art, Hindu Art, <PERSON>, Lord Vishnu Wallpapers, <PERSON>, Hindu Culture, Hindu Dharma, Indian Goddess, Egyptian Symbols'}, {24: 'Occupational therapist (or medical professional) assembling a brain jigsaw puzzle. Concept picture for cognitive rehabilitation in Alzheimer disease and dementia patient.'}, {25: '2018 Genesis Open: Round 1 - <PERSON> and <PERSON> to the Ninth Hole'}, {26: 'A drawing of the lavatory'}, {27: 'Room, The Blackstone, Autograph Collection'}, {28: "Some Helpful Ideas For Training Your Dog. Loving your dog does not mean you are willing to let him go hog wild on your possessions. That said, your dog doesn't feel the same way. Siberian Husky Funny, Siberian Husky Training, Siberian Huskies, Most Beautiful Dogs, Old Dogs, Training Your Dog, Pitbull Terrier, <PERSON>, Dog Breeds"}, {29: 'The <PERSON>, Mare, <PERSON>, Animal, Horses, Bay Horse, Bay'}]
# Raw output is ```json
# {
#     "20": "Weathered Burford Walling in natural light - This light yellow reconstituted stone wall has grey accents and a tumbled texture, available in three different sizes. Perfect for concrete paving, patio slabs, modern garden design, cladding, and garden projects.",
#     "21": "The Franklin Inn serves as a gathering spot for locals, known for its good food and enjoyable atmosphere.",
#     "22": "The rocks appeared quite different in the brief moments of sunlight I experienced that morning.",
#     "23": "Churning of the Cosmic Ocean by Ravi Varma Press Lithograph. Featuring Shiva Art and Hindu themes, along with Indian deities and cultural symbols.",
#     "24": "An occupational therapist or healthcare professional working on assembling a brain puzzle. This image represents cognitive rehabilitation for Alzheimer's and dementia patients.",
#     "25": "2018 Genesis Open: First Round - Contestants approaching the Ninth Hole.",
#     "26": "A sketch of a restroom.",
#     "27": "The Blackstone room, part of the Autograph Collection.",
#     "28": "Helpful Tips for Training Your Dog. Loving your dog doesn't mean allowing them to destroy your belongings. However, your dog may not share this understanding. Features Siberian Huskies, training tips, and various dog breeds.",
#     "29": "The Mare, and other Horses, showcasing a bay horse."
# }
# ```
# Output dict is  {'20': 'Weathered Burford Walling in natural light - This light yellow reconstituted stone wall has grey accents and a tumbled texture, available in three different sizes. Perfect for concrete paving, patio slabs, modern garden design, cladding, and garden projects.', '21': 'The Franklin Inn serves as a gathering spot for locals, known for its good food and enjoyable atmosphere.', '22': 'The rocks appeared quite different in the brief moments of sunlight I experienced that morning.', '23': 'Churning of the Cosmic Ocean by Ravi Varma Press Lithograph. Featuring Shiva Art and Hindu themes, along with Indian deities and cultural symbols.', '24': "An occupational therapist or healthcare professional working on assembling a brain puzzle. This image represents cognitive rehabilitation for Alzheimer's and dementia patients.", '25': '2018 Genesis Open: First Round - Contestants approaching the Ninth Hole.', '26': 'A sketch of a restroom.', '27': 'The Blackstone room, part of the Autograph Collection.', '28': "Helpful Tips for Training Your Dog. Loving your dog doesn't mean allowing them to destroy your belongings. However, your dog may not share this understanding. Features Siberian Huskies, training tips, and various dog breeds.", '29': 'The Mare, and other Horses, showcasing a bay horse.'}
# [{30: 'Hotel Du Lac: Old furniture and TV that is not working'}, {31: 'The Garden of Eden painting - <PERSON> The Garden of Eden art painting'}, {32: 'Kitchen of The Orchard, Brookfield Avenue, Rainhill, Prescot L35'}, {33: 'The Private Collection of Antique Cars of H.S.H. Prince <PERSON>: Mercedes gull-wing.'}, {34: 'Pumpkin in a zombie hand stock illustration'}, {35: 'The 27 Maps That Explain America - Business Insider - photo#25'}, {36: 'Runners pass the Radcliffe Camera during the 2018 Oxford Half Marathon'}, {37: 'Gold lettering happy Birthday on a dark background.'}, {38: 'Splash vibrant color on your walls or any flat surface with a watercolor world map decal sticker. Watercolor World Map Wall Decal by Decal Sticker Wall Stickers World Map, World Map Wall Art, World Map Decal, Wall Maps, Vinyl Wall Stickers, Wall Decals, Mural Wall, Wall Vinyl, Car Stickers'}, {39: 'The Chrysler Building is reflected in a sidewalk puddle on 42nd St. in April 1954.'}]
# Raw output is {
#     "30": "Hotel Du Lac: Old furnishings and a malfunctioning TV.",
#     "31": "The Garden of Eden artwork - <PERSON> The Garden of Eden painting.",
#     "32": "Kitchen at The Orchard, Brookfield Avenue, Rainhill, Prescot L35.",
#     "33": "H.S.H. Prince <PERSON>'s Private Antique Car Collection: Mercedes gull-wing.",
#     "34": "Pumpkin held by a zombie hand in a stock illustration.",
#     "35": "27 Maps That Explain America - Business Insider - photo#25.",
#     "36": "Runners passing by the Radcliffe Camera during the 2018 Oxford Half Marathon.",
#     "37": "Gold lettering wishing a happy birthday on a dark backdrop.",
#     "38": "Add a splash of color to your walls or surfaces with a watercolor world map decal. Watercolor World Map Wall Decal by Decal Sticker Wall Stickers.",
#     "39": "The Chrysler Building's reflection in a puddle on 42nd St. in April 1954."
# }
# Output dict is  {'30': 'Hotel Du Lac: Old furnishings and a malfunctioning TV.', '31': 'The Garden of Eden artwork - <PERSON> The Garden of Eden painting.', '32': 'Kitchen at The Orchard, Brookfield Avenue, Rainhill, Prescot L35.', '33': "H.S.H. Prince <PERSON>'s Private Antique Car Collection: Mercedes gull-wing.", '34': 'Pumpkin held by a zombie hand in a stock illustration.', '35': '27 Maps That Explain America - Business Insider - photo#25.', '36': 'Runners passing by the Radcliffe Camera during the 2018 Oxford Half Marathon.', '37': 'Gold lettering wishing a happy birthday on a dark backdrop.', '38': 'Add a splash of color to your walls or surfaces with a watercolor world map decal. Watercolor World Map Wall Decal by Decal Sticker Wall Stickers.', '39': "The Chrysler Building's reflection in a puddle on 42nd St. in April 1954."}
# [{40: 'This image may contain Sandwich Food Plant and Bread'}, {41: 'Mercedes 280SL W113 Pagoda Values, Two Great Cars, Two Very Different Prices at the Same Auction'}, {42: 'A <PERSON> home with stucco siding and a brick-lined arched entryway. Its roofline has a tall, steep slope on the left and a smaller gable on the right.'}, {43: 'World of Tanks wallpaper, girl, the sun, figure, shorts, <PERSON> wallpaper'}, {44: 'Italian Bronze Tuscany Neoclassical Style Sculpture Featuring a Relaxed Woman For Sale 4'}, {45: 'Hand throwing a frisbee disc in the park on a summer day'}, {46: 'The story of British Columbia at the Royal BC Museum - replica of the Discovery ship'}, {47: "Surrounding environment The Vagabond's House Boutique Inn & Spa Studio"}, {48: "Sand running through an hour glass - don't delay paying into your pension"}, {49: 'White Wolf, World of Darkness, <PERSON>. Vampire The Requiem, World Of Darkness, White Wolf, Dream Art, Being In The World, Dark Ages, <PERSON>, Vampires, Monsters'}]
# Raw output is ```json
# {
#     "40": "This picture may feature Sandwich Food Plant and Bread.",
#     "41": "Mercedes 280SL W113 Pagoda Prices, Two Remarkable Cars, Two Distinct Costs at the Same Auction.",
#     "42": "A residence with stucco exterior and a brick-arched entrance. It has a tall, steep roof slope on one side and a shorter gable on the other.",
#     "43": "World of Tanks wallpaper, girl, sunlight, figure, shorts, character wallpaper.",
#     "44": "Italian Bronze Tuscany Neoclassical Sculpture Depicting a Relaxed Woman Available for Sale 4.",
#     "45": "A hand tossing a frisbee in the park on a warm summer day.",
#     "46": "The narrative of British Columbia at the Royal BC Museum - a replica of the Discovery ship.",
#     "47": "Nearby setting of The Vagabond's House Boutique Inn & Spa Studio.",
#     "48": "Sand trickling through an hourglass - don’t procrastinate on contributing to your pension.",
#     "49": "White Wolf, World of Darkness, character. Vampire The Requiem, World Of Darkness, White Wolf, Dream Art, Existing In The World, Dark Ages, character, Vampires, Monsters."
# }
# ```
# Output dict is  {'40': 'This picture may feature Sandwich Food Plant and Bread.', '41': 'Mercedes 280SL W113 Pagoda Prices, Two Remarkable Cars, Two Distinct Costs at the Same Auction.', '42': 'A residence with stucco exterior and a brick-arched entrance. It has a tall, steep roof slope on one side and a shorter gable on the other.', '43': 'World of Tanks wallpaper, girl, sunlight, figure, shorts, character wallpaper.', '44': 'Italian Bronze Tuscany Neoclassical Sculpture Depicting a Relaxed Woman Available for Sale 4.', '45': 'A hand tossing a frisbee in the park on a warm summer day.', '46': 'The narrative of British Columbia at the Royal BC Museum - a replica of the Discovery ship.', '47': "Nearby setting of The Vagabond's House Boutique Inn & Spa Studio.", '48': 'Sand trickling through an hourglass - don’t procrastinate on contributing to your pension.', '49': 'White Wolf, World of Darkness, character. Vampire The Requiem, World Of Darkness, White Wolf, Dream Art, Existing In The World, Dark Ages, character, Vampires, Monsters.'}
# [{50: 'These Dogs Here Are Real American Pit Bull Terriers Aka Bulls Pits'}, {51: "The Climber's jersey is solely focussed on dumping excess heat"}, {52: 'The Old Vicarage in High Street, now Barclays Bank, Henley in Arden. 1973 | IMAGE LOCATION: (Warwickshire County Record Office)'}, {53: 'Flat colored isolated striped ice cream sprinkled with glaze of blue color. On a wooden stick. With a little pink butterfly. Simple drawing on a white royalty free illustration'}, {54: 'A family trying to quickly pack a Perth home.'}, {55: 'Man in office suit meditating under a glass dome while people running around panicking. Self-quarantine, stay home. Man in office suit meditating under a glass royalty free illustration'}, {56: 'A stretchable and compressible sensor for wearable electronics and soft robots'}, {57: 'Spa Valley Railway: Waiting a train at Groombridge Loop. Copyright <PERSON>.'}, {58: 'The First Official Confederate Flag'}, {59: 'Blonde girl in Gilded Intent jeans with a step hem and heels. She is in a white shirt.'}]
# Raw output is {
#     "50": "These dogs are genuine American Pit Bull Terriers, also known as Bull Pits.",
#     "51": "The climber's jersey is designed to efficiently release excess heat.",
#     "52": "The Old Vicarage on High Street, which is now Barclays Bank, Henley in Arden. 1973 | IMAGE LOCATION: (Warwickshire County Record Office)",
#     "53": "A flat, colorful striped ice cream cone adorned with a blue glaze. It has a wooden stick and features a small pink butterfly. Simple illustration on a white background.",
#     "54": "A family hurriedly packing up a home in Perth.",
#     "55": "A man in an office suit meditates under a glass dome while chaos ensues around him. Self-quarantine, stay at home. Man meditating in an office suit in a glass illustration.",
#     "56": "A flexible and compressible sensor intended for wearable gadgets and soft robotics.",
#     "57": "Spa Valley Railway: Awaiting a train at Groombridge Loop. Copyright <PERSON>.",
#     "58": "The first official flag of the Confederacy.",
#     "59": "A blonde girl wearing Gilded Intent jeans with a step hem and heels, paired with a white shirt."
# }
# Output dict is  {'50': 'These dogs are genuine American Pit Bull Terriers, also known as Bull Pits.', '51': "The climber's jersey is designed to efficiently release excess heat.", '52': 'The Old Vicarage on High Street, which is now Barclays Bank, Henley in Arden. 1973 | IMAGE LOCATION: (Warwickshire County Record Office)', '53': 'A flat, colorful striped ice cream cone adorned with a blue glaze. It has a wooden stick and features a small pink butterfly. Simple illustration on a white background.', '54': 'A family hurriedly packing up a home in Perth.', '55': 'A man in an office suit meditates under a glass dome while chaos ensues around him. Self-quarantine, stay at home. Man meditating in an office suit in a glass illustration.', '56': 'A flexible and compressible sensor intended for wearable gadgets and soft robotics.', '57': 'Spa Valley Railway: Awaiting a train at Groombridge Loop. Copyright <PERSON>.', '58': 'The first official flag of the Confederacy.', '59': 'A blonde girl wearing Gilded Intent jeans with a step hem and heels, paired with a white shirt.'}
# [{60: "Today's Harvest: We carry a wide array of Jams, Preserves, Pickles, and Sauces"}, {61: 'The Exeter to Plymouth line hugs the coast at Dawlish, Devon, England Dorset Coast, Cornwall Coast, Devon And Cornwall, Exeter England, England Uk, Plymouth England, Devon Holidays, Places To Travel, Places To Visit'}, {62: 'Man checking the calendar app on his iPhone mobile smartphone, HD wallpaper'}, {63: 'A man laughs while scratching his chin against an indistinct dark background.'}, {64: 'Beaches with the clearest water, Six Senses Laamu Maldives'}, {65: 'A Spanish sign for the bathrooms in Ecuador'}, {66: 'Brand design and corporate identity for a dance and fitness center.'}, {67: 'Gray british cat sitting on a bluish rug stock images'}, {68: 'The Westin Resort & Spa, Puerto Vallarta: Lounge area'}, {69: 'Gradient shaded cartoon globe of the world. A creative illustrated gradient shaded cartoon globe of the world stock illustration'}]
# Raw output is ```json
# {
#   "60": "Today's Selection: We offer a diverse range of Jams, Preserves, Pickles, and Sauces.",
#   "61": "The train route from Exeter to Plymouth follows the coast at Dawlish, England.",
#   "62": "A person looking at the calendar app on his iPhone smartphone, high-definition wallpaper.",
#   "63": "A man chuckles while rubbing his chin against a blurred dark backdrop.",
#   "64": "Beaches with crystal clear waters, Six Senses Laamu Maldives.",
#   "65": "A Spanish restroom sign in Ecuador.",
#   "66": "Branding and corporate identity for a dance and fitness studio.",
#   "67": "A gray British cat perched on a bluish carpet.",
#   "68": "Lounge area at The Westin Resort & Spa, Puerto Vallarta.",
#   "69": "A creatively illustrated cartoon globe of the world with a gradient shade."
# }
# ```
# Output dict is  {'60': "Today's Selection: We offer a diverse range of Jams, Preserves, Pickles, and Sauces.", '61': 'The train route from Exeter to Plymouth follows the coast at Dawlish, England.', '62': 'A person looking at the calendar app on his iPhone smartphone, high-definition wallpaper.', '63': 'A man chuckles while rubbing his chin against a blurred dark backdrop.', '64': 'Beaches with crystal clear waters, Six Senses Laamu Maldives.', '65': 'A Spanish restroom sign in Ecuador.', '66': 'Branding and corporate identity for a dance and fitness studio.', '67': 'A gray British cat perched on a bluish carpet.', '68': 'Lounge area at The Westin Resort & Spa, Puerto Vallarta.', '69': 'A creatively illustrated cartoon globe of the world with a gradient shade.'}
# [{70: 'The <PERSON> Tote Laptop Bag for Women 15-inch - Laptop Bags Australia'}, {71: 'The Company Men movie scenes'}, {72: 'Duck and Dumplings is a new twist on a Southern classic dish'}, {73: 'The Wickford House in Wickford, R.I.'}, {74: 'In-Room Dining, 101 Newport Condo Across the Airport'}, {75: 'Which Breed Of Horse Is this?'}, {76: 'The Detailed Itinerary You NEED for a Long Birthday Weekend in Mexico City'}, {77: 'A Day at The Beach - Portraits'}, {78: 'An explosion on the launch site of a SpaceX Falcon 9 rocket. Photo: Reuters'}, {79: 'The first Outlaws consisting of Starfire and Arsenal, and the new Outlaws Bizarro and Artemis. From -- Red Hood and the Outlaws Vol. Artemis, Comic Art, Comic Books, Red Hood <PERSON>, Nerd, Dc Comics Art, Batman Family, Dc Movies, Comic Panels'}]
# Raw output is ```json
# {
#     "70": "The 15-inch Tote Laptop Bag for Women - Laptop Bags Australia",
#     "71": "Scenes from the movie The Company Men",
#     "72": "Duck and Dumplings offers a fresh take on a traditional Southern dish",
#     "73": "The Wickford House located in Wickford, R.I.",
#     "74": "In-Room Dining at 101 Newport Condo Near the Airport",
#     "75": "What breed of horse is this?",
#     "76": "Your Essential Itinerary for a Long Birthday Weekend in Mexico City",
#     "77": "A Day at the Beach - A Series of Portraits",
#     "78": "An explosion at the SpaceX Falcon 9 launch site. Photo: Reuters",
#     "79": "The original Outlaws featuring Starfire and Arsenal, along with the new Outlaws Bizarro and Artemis. From -- Red Hood and the Outlaws Vol. Artemis, Comic Art, Comic Books, Red Hood, Nerd, DC Comics Art, Batman Family, DC Movies, Comic Panels"
# }
# ```
# Output dict is  {'70': 'The 15-inch Tote Laptop Bag for Women - Laptop Bags Australia', '71': 'Scenes from the movie The Company Men', '72': 'Duck and Dumplings offers a fresh take on a traditional Southern dish', '73': 'The Wickford House located in Wickford, R.I.', '74': 'In-Room Dining at 101 Newport Condo Near the Airport', '75': 'What breed of horse is this?', '76': 'Your Essential Itinerary for a Long Birthday Weekend in Mexico City', '77': 'A Day at the Beach - A Series of Portraits', '78': 'An explosion at the SpaceX Falcon 9 launch site. Photo: Reuters', '79': 'The original Outlaws featuring Starfire and Arsenal, along with the new Outlaws Bizarro and Artemis. From -- Red Hood and the Outlaws Vol. Artemis, Comic Art, Comic Books, Red Hood, Nerd, DC Comics Art, Batman Family, DC Movies, Comic Panels'}
# [{80: 'Arrange flowers like a pro - Dandelion Ranch Floral Arrangements'}, {81: "A diagram showing <PERSON>'s Quality Systems Escalation Process Flow"}, {82: 'Writing note showing Be The Light. Business photo showcasing Enlighten other showing with your attitude be optimistic. Writing note showing Be The Light stock illustration'}, {83: 'Hydrangea macrophylla - <PERSON> flower - Beautiful bush of hydrangea flowers in a garden'}, {84: 'Rooms with a blue sofa, built-in wardrobe, wooden floor stock photography'}, {85: 'UCLA student dentist <PERSON> sees an Operation Bruin Smiles patient, UCLA student veteran <PERSON>.'}, {86: 'Appleby Fair, washing the horses, River Eden'}, {87: '<PERSON> printed texture in graduated mid and light blue. A lino printed background texture scanned from a lino print and colorized in mid and light blue royalty free illustration'}, {88: 'Fruits alphabet a is for apricot fruits'}, {89: 'The delicate looking 101 Spaghetti chair with black enameled steel legs and a backrest and seat made of natural leather was designed by <PERSON> for the Italian manufacturer Alias in 1980. A symbol in the history of design, Spaghetti is'}]
# Raw output is {
#     "80": "Create floral arrangements like an expert - Dandelion Ranch Floral Designs",
#     "81": "A diagram illustrating a quality systems escalation process flow",
#     "82": "A note that says Be The Light. A business image promoting optimism and encouraging others with your attitude. A note illustrating Be The Light.",
#     "83": "Hydrangea macrophylla - Stunning bush of hydrangea flowers in bloom",
#     "84": "Photos of a room featuring a blue sofa, built-in wardrobe, and wooden flooring",
#     "85": "A dental student at UCLA treats an Operation Bruin Smiles patient, a student veteran.",
#     "86": "Appleby Fair, bathing the horses along the River Eden",
#     "87": "A textured print in graduated shades of mid and light blue. A scanned and colorized lino print texture.",
#     "88": "Fruits alphabet: A is for apricot.",
#     "89": "The elegantly designed 101 Spaghetti chair with black enameled steel legs and a natural leather backrest and seat was created by an iconic designer for Alias in 1980, marking a milestone in design history."
# }
# Output dict is  {'80': 'Create floral arrangements like an expert - Dandelion Ranch Floral Designs', '81': 'A diagram illustrating a quality systems escalation process flow', '82': 'A note that says Be The Light. A business image promoting optimism and encouraging others with your attitude. A note illustrating Be The Light.', '83': 'Hydrangea macrophylla - Stunning bush of hydrangea flowers in bloom', '84': 'Photos of a room featuring a blue sofa, built-in wardrobe, and wooden flooring', '85': 'A dental student at UCLA treats an Operation Bruin Smiles patient, a student veteran.', '86': 'Appleby Fair, bathing the horses along the River Eden', '87': 'A textured print in graduated shades of mid and light blue. A scanned and colorized lino print texture.', '88': 'Fruits alphabet: A is for apricot.', '89': 'The elegantly designed 101 Spaghetti chair with black enameled steel legs and a natural leather backrest and seat was created by an iconic designer for Alias in 1980, marking a milestone in design history.'}
# [{90: 'Real Weddings Milton Keynes: A DIY bride and a homemade celebration'}, {91: 'A grungy and worn hazard stripes texture. EPS 8. Vector file included royalty free illustration'}, {92: 'People on Twitter are hilariously confused by this coffee riddle.'}, {93: 'The official Arctic White Stingray Corvette Photo Thread - Cars & Motorcycles Club Corvette C7 Stingray, Corvette Summer, 2015 Corvette, Prom Car, Bentley Mulsanne, Best Classic Cars, Poker Online, Sport Cars, Supercars'}, {94: "Guests on the dance floor at Cutlers' Hall Sheffield"}, {95: 'Hand crafted means made by hand ! All the hats are formed on wooden blocks by hand , not mechanically .'}, {96: 'Proposal photography at the Palace of Fine Arts'}, {97: 'Vector paper cut illustration of a black hole in cosmos stock illustration'}, {98: 'Austin Healey Sprite: car of the week'}, {99: 'A young woman sleeps on a double bed in a dark room, her face buried in the covers.'}]
# Raw output is {
#     "90": "Weddings in Milton Keynes: A bride's DIY journey and a homemade celebration",
#     "91": "A rough and aged hazard stripes texture. EPS 8. Vector file included as a royalty-free illustration",
#     "92": "Twitter users are amusingly perplexed by this coffee riddle.",
#     "93": "The official photo thread for the Arctic White Stingray Corvette - Cars & Motorcycles Club featuring Corvette C7, Corvette Summer, 2015 Corvette, Prom Car, Bentley Mulsanne, Classic Cars, Poker Online, Sport Cars, Supercars",
#     "94": "Dancers enjoying themselves at Cutlers' Hall in Sheffield",
#     "95": "Handcrafted signifies made by hand! Each hat is shaped on wooden blocks manually, not by machines.",
#     "96": "Engagement photography at the Palace of Fine Arts",
#     "97": "Vector illustration representing a paper cut black hole in the cosmos",
#     "98": "Austin Healey Sprite: vehicle of the week",
#     "99": "A young woman rests on a double bed in a dimly lit room, her face covered by the blankets."
# }
# Output dict is  {'90': "Weddings in Milton Keynes: A bride's DIY journey and a homemade celebration", '91': 'A rough and aged hazard stripes texture. EPS 8. Vector file included as a royalty-free illustration', '92': 'Twitter users are amusingly perplexed by this coffee riddle.', '93': 'The official photo thread for the Arctic White Stingray Corvette - Cars & Motorcycles Club featuring Corvette C7, Corvette Summer, 2015 Corvette, Prom Car, Bentley Mulsanne, Classic Cars, Poker Online, Sport Cars, Supercars', '94': "Dancers enjoying themselves at Cutlers' Hall in Sheffield", '95': 'Handcrafted signifies made by hand! Each hat is shaped on wooden blocks manually, not by machines.', '96': 'Engagement photography at the Palace of Fine Arts', '97': 'Vector illustration representing a paper cut black hole in the cosmos', '98': 'Austin Healey Sprite: vehicle of the week', '99': 'A young woman rests on a double bed in a dimly lit room, her face covered by the blankets.'}
# [{100: 'The real difference between Swiss and Belgian chocolate, explained'}, {101: 'Periodic Table of The Elements Chart Chemical Science Poster Prints Wall Art Painting Wall Pictures For Living Room Home Decor'}, {102: 'Media of Build a Rocket'}, {103: "The bride and groom share a kiss on the courthouse balcony after saying ``I do.''"}, {104: 'A Blue and White DIY Country Wedding'}, {105: 'Medical supplies and beds are seen inside a tent as volunteers from the International Christian relief organization Samaritans Purse set up an Emergency Field Hospital'}, {106: 'Photo of The Sacred Laterite: Temple trail in North Malabar by Anand V'}, {107: '2020 Freightliner® M2 106 medium duty truck set against a white background'}, {108: '1968 Vintage <PERSON> on a Beach Painting For Sale - Image 6 of 10'}, {109: '1934 a $20 dollar bill star federal reserve note old paper money small size notes photo 1'}]
# Raw output is ```json
# {
#     "100": "An explanation of the key differences between Swiss and Belgian chocolate.",
#     "101": "A chart of the Periodic Table of Elements, designed as a poster for chemical science art in home decor.",
#     "102": "Media related to constructing a rocket.",
#     "103": "The newlyweds share a kiss on the courthouse balcony after their vows.",
#     "104": "A DIY country wedding featuring blue and white themes.",
#     "105": "Inside a tent, medical equipment and beds are arranged as volunteers from a Christian relief organization establish an Emergency Field Hospital.",
#     "106": "Image of The Sacred Laterite: Temple trail in North Malabar by Anand V.",
#     "107": "A 2020 Freightliner® M2 106 medium duty truck displayed against a white backdrop.",
#     "108": "For sale: A vintage 1968 painting of <PERSON> on the beach - Image 6 of 10.",
#     "109": "Photo of a $20 star federal reserve note from 1934, representing old paper currency."
# }
# ```
# Output dict is  {'100': 'An explanation of the key differences between Swiss and Belgian chocolate.', '101': 'A chart of the Periodic Table of Elements, designed as a poster for chemical science art in home decor.', '102': 'Media related to constructing a rocket.', '103': 'The newlyweds share a kiss on the courthouse balcony after their vows.', '104': 'A DIY country wedding featuring blue and white themes.', '105': 'Inside a tent, medical equipment and beds are arranged as volunteers from a Christian relief organization establish an Emergency Field Hospital.', '106': 'Image of The Sacred Laterite: Temple trail in North Malabar by Anand V.', '107': 'A 2020 Freightliner® M2 106 medium duty truck displayed against a white backdrop.', '108': 'For sale: A vintage 1968 painting of <PERSON> on the beach - Image 6 of 10.', '109': 'Photo of a $20 star federal reserve note from 1934, representing old paper currency.'}
# [{110: 'Crowne Plaza Johannesburg - The Rosebank, Johannesburg'}, {111: 'All White Spring Outfit, Leith Drape Front Jacket, DIY <PERSON>, <PERSON> Yardley Sandals'}, {112: "``Close-up of a paint tube and brushes'' Canvas Wall Art"}, {113: 'Shaggy matted hair dog sitting outside on a sunny day'}, {114: 'Close up of a slice of light and fluffy easy vegan sponge cake with vanilla icing and berries'}, {115: 'A Brief History of Beginning Reading Instruction What are the assumptions about children and about reading made in the development of each text.'}, {116: "The Children's garden book review"}, {117: 'The Taj - Indian Restaurant'}, {118: 'The Hansa Life-Size Kangaroo and <PERSON> (baby kangaroo) Plush Stuffed Animal is a realistic reproduction of this familiar animal from Down Under. This Hansa plush stuffed animal price includes ground shipping. <PERSON>, Giant Stuffed Animals, Stuffed Toys, Animal Habitats, Plush Animals, Soft Sculpture, <PERSON>, Toys For Boys, Toys'}, {119: '1 bedroom condo for rent at The Seed Sathorn Taksin'}]
# Raw output is ```json
# {
#     "110": "Crowne Plaza Johannesburg - The Rosebank",
#     "111": "All White Spring Outfit featuring a Leith Drape Front Jacket and DIY sandals",
#     "112": "Close-up of a canvas wall art depicting a paint tube and brushes",
#     "113": "A shaggy dog sitting outside on a sunny day",
#     "114": "Close-up of a light, fluffy vegan sponge cake with vanilla icing and berries",
#     "115": "An Overview of Early Reading Instruction: Exploring assumptions about children and reading in various texts.",
#     "116": "Review of a Children's Garden Book",
#     "117": "The Taj - Indian Cuisine",
#     "118": "The Hansa Life-Size Kangaroo and baby kangaroo plush toy is a realistic representation of this iconic animal from Australia, and the price includes ground shipping.",
#     "119": "1 bedroom condo available for rent at The Seed Sathorn Taksin"
# }
# ```
# Output dict is  {'110': 'Crowne Plaza Johannesburg - The Rosebank', '111': 'All White Spring Outfit featuring a Leith Drape Front Jacket and DIY sandals', '112': 'Close-up of a canvas wall art depicting a paint tube and brushes', '113': 'A shaggy dog sitting outside on a sunny day', '114': 'Close-up of a light, fluffy vegan sponge cake with vanilla icing and berries', '115': 'An Overview of Early Reading Instruction: Exploring assumptions about children and reading in various texts.', '116': "Review of a Children's Garden Book", '117': 'The Taj - Indian Cuisine', '118': 'The Hansa Life-Size Kangaroo and baby kangaroo plush toy is a realistic representation of this iconic animal from Australia, and the price includes ground shipping.', '119': '1 bedroom condo available for rent at The Seed Sathorn Taksin'}
# [{120: 'Every heart has a window. You can look from your own heart into another. - <PERSON>, persian poet and mystic, <PERSON>, <PERSON> Quotes, Interesting Quotes, Amazing Quotes, <PERSON>, Take What You Need, Sufi, Spiritual Awakening, True Words'}, {121: 'Generator Barcelona is a design-led & party hostel in Barcelona near La Sagrada Familia in the district of Gràcia. Book your private or shared room with us! Barcelona Hotels, Concrete Tiles, Hanging Lanterns, Flooring, Chair, Room, Furniture, Design, Home Decor'}, {122: "Romantic Valentine's Day Gift Quote Sign - Lord of the Rings Wall Art"}, {123: "Promote goodwill to all men and women with these random acts of kindness poster for class. Perfect to display in your classes near to World Kindness Day. Kids And Parenting, Parenting Hacks, Children's Mental Health Week, World Kindness Day, Random Acts, School Lessons, Class Management, Teaching English, Your Child"}, {124: 'Poor slums are springing up in the suburbs of Yangon. (Photo: <PERSON>/Myanmar Now)'}, {125: "``Walden'' by Hygienic Dress League - part of a two-sided mural that lives on a barn on Ziel Farm, located on the corner of <PERSON> and Van Dyke Road."}, {126: 'Ways to Help Kids Fall Asleep easier at night, and go to bed without a fight. Make bedtime with the kids easier and better with a simple bedtime routine and these 10 easy tips and ways to help kids fall asleep at night. | Parenting | Kids'}, {127: 'Image of the Camden Building for Truckee Commercial Properties'}, {128: 'The Play Naturally Log Crawl Playground Tunnel is a nature-inspired log replica tunnel for your playground. Dog Playground, Preschool Playground, Backyard Playground, Backyard Games, Backyard Projects, Playground Ideas, Outdoor Toys, Outdoor Spaces, Parking Design'}, {129: 'Chicken coop building 101 is my way of sharing my knowledge on chickens and chicken coop with you guys out there. I hope you enjoy this article and find it helpful. In my opinion chickens are my number one farmyard animal. Chickens And Roosters, Pet Chickens, Raising Chickens, Chicken Coop Plans, Building A Chicken Coop, Chicken Runs, Chicken Art, <PERSON>, Chickens Backyard'}]
# Raw output is {
#   "120": "Each heart has its own window, allowing us to see into another's. - Persian poet and mystic, True Words, Sufi, Spiritual Awakening.",
#   "121": "Generator Barcelona is a design-focused party hostel close to La Sagrada Familia in the Gràcia district. Reserve your private or shared room today!",
#   "122": "Valentine's Day Gift Quote Sign inspired by Lord of the Rings Wall Art.",
#   "123": "Spread goodwill with this random acts of kindness poster for classrooms, ideal for World Kindness Day displays.",
#   "124": "Shantytowns are emerging in the outskirts of Yangon. (Photo: Myanmar Now)",
#   "125": "'Walden' created by Hygienic Dress League is a part of a two-sided mural located on Ziel Farm's barn at the intersection of Van Dyke Road.",
#   "126": "Tips to help children fall asleep more easily and improve bedtime routines with these 10 suggestions.",
#   "127": "Photo of the Camden Building for Truckee Commercial Properties.",
#   "128": "The Play Naturally Log Crawl Playground Tunnel is a nature-inspired log tunnel designed for playgrounds.",
#   "129": "Chicken coop building 101 shares my knowledge about chickens and how to build chicken coops. Chickens are my favorite farm animals."
# }
# Output dict is  {'120': "Each heart has its own window, allowing us to see into another's. - Persian poet and mystic, True Words, Sufi, Spiritual Awakening.", '121': 'Generator Barcelona is a design-focused party hostel close to La Sagrada Familia in the Gràcia district. Reserve your private or shared room today!', '122': "Valentine's Day Gift Quote Sign inspired by Lord of the Rings Wall Art.", '123': 'Spread goodwill with this random acts of kindness poster for classrooms, ideal for World Kindness Day displays.', '124': 'Shantytowns are emerging in the outskirts of Yangon. (Photo: Myanmar Now)', '125': "'Walden' created by Hygienic Dress League is a part of a two-sided mural located on Ziel Farm's barn at the intersection of Van Dyke Road.", '126': 'Tips to help children fall asleep more easily and improve bedtime routines with these 10 suggestions.', '127': 'Photo of the Camden Building for Truckee Commercial Properties.', '128': 'The Play Naturally Log Crawl Playground Tunnel is a nature-inspired log tunnel designed for playgrounds.', '129': 'Chicken coop building 101 shares my knowledge about chickens and how to build chicken coops. Chickens are my favorite farm animals.'}
# [{130: 'Volunteers sort plastic waste at a brand audit in Mumbai, India, image via Break Free From Plastic.'}, {131: 'Sleeping fox put a muzzle on the tail. One fox curled up asleep with his head on the tail stock illustration'}, {132: 'The exciting Exterior Desi House Design Luxury Homes Exterior With Mansion Exterior Design image below, is other parts of The ... Interior Design Images, Residential Interior Design, Contemporary Interior, Interior Ideas, Interior Architecture, Luxury Homes Exterior, Exterior Design, Classic House Design, Interior Fit Out'}, {133: 'Garden, Home and Party: The importance of being blue'}, {134: 'Vector 3D Muslim Pelita Oil Lamp Ramadan Money Green Packet Design. Translation: Ramadan Kareem - May Generosity Bless You During The Holy Month.'}, {135: 'Pregnant woman standing at the window in the beautiful azure dress. Portrait of a girl preparing to become a mother. The woman in stock photos'}, {136: 'The Young Rascals poster, 1967'}, {137: 'Special text The purpose of using special text such as italics or bold is to. A) To make the text attractive and easy to read.'}, {138: 'Locate the plastic push pins along the bottom of the bumper.'}, {139: "The Mosaic Table is a commission for restaurant at 15 York Street in downtown Toronto. The fourteen foot communal table is composed of antique hemlock that was buried below York Street for over a century as a part of the historic <PERSON>'s Wharf. Woodworking Shop, Woodworking Plans, Wood Furniture, Furniture Design, Furniture Ideas, Custom Furniture, Wood Table Design, Table Designs, Table Cafe"}]
# Raw output is ```json
# {
#     "130": "Volunteers categorize plastic waste during a brand audit in Mumbai, India, image courtesy of Break Free From Plastic.",
#     "131": "A sleeping fox rests its head on its tail. Illustration of a fox curled up in slumber.",
#     "132": "The captivating exterior desi house design featuring luxury homes shown below is part of The ... Interior Design Images, Residential Architecture, Modern Interior, Interior Concepts, Luxury Homes Exterior, Classic House Design.",
#     "133": "Garden, Home, and Celebration: The significance of the color blue.",
#     "134": "3D vector design of a Muslim Pelita oil lamp and Ramadan green packet. Translation: Ramadan Kareem - Wishing you generosity during the holy month.",
#     "135": "A pregnant woman, dressed in a stunning azure gown, stands by the window. A portrait of a woman awaiting motherhood.",
#     "136": "The Young Rascals movie poster from 1967.",
#     "137": "The use of highlighted text such as italics or bold serves a purpose. A) To enhance the text's appeal and readability.",
#     "138": "Find the plastic push pins at the bottom of the bumper.",
#     "139": "The Mosaic Table is a commissioned piece for a restaurant located at 15 York Street in downtown Toronto. This fourteen-foot communal table is made from antique hemlock that was buried beneath York Street for over a century as part of the historic Wharf."
# }
# ```
# Output dict is  {'130': 'Volunteers categorize plastic waste during a brand audit in Mumbai, India, image courtesy of Break Free From Plastic.', '131': 'A sleeping fox rests its head on its tail. Illustration of a fox curled up in slumber.', '132': 'The captivating exterior desi house design featuring luxury homes shown below is part of The ... Interior Design Images, Residential Architecture, Modern Interior, Interior Concepts, Luxury Homes Exterior, Classic House Design.', '133': 'Garden, Home, and Celebration: The significance of the color blue.', '134': '3D vector design of a Muslim Pelita oil lamp and Ramadan green packet. Translation: Ramadan Kareem - Wishing you generosity during the holy month.', '135': 'A pregnant woman, dressed in a stunning azure gown, stands by the window. A portrait of a woman awaiting motherhood.', '136': 'The Young Rascals movie poster from 1967.', '137': "The use of highlighted text such as italics or bold serves a purpose. A) To enhance the text's appeal and readability.", '138': 'Find the plastic push pins at the bottom of the bumper.', '139': 'The Mosaic Table is a commissioned piece for a restaurant located at 15 York Street in downtown Toronto. This fourteen-foot communal table is made from antique hemlock that was buried beneath York Street for over a century as part of the historic Wharf.'}
# [{140: 'The COMPASS III Hardwood Floor Medallion Inlay'}, {141: 'For sale an <PERSON> house in Sharjah, Al Qadisiyah area'}, {142: 'Strike Up The Band, <PERSON>, 1940--Photo displayed on a wall'}, {143: 'Like a hook carved out of the ocean, sea stacks abound along the coast of south Westland'}, {144: 'Flowers of the Foxglove - Digitalis purpurea'}, {145: 'Uyghur seller at the Kashgar market, Xinjiang, China'}, {146: 'The Magnolia Hotel & Spa'}, {147: 'This super rare Aston Martin Vanquish <PERSON> is being offered as a matching pair with this Zagato coupe by Only sold as a pair. Aston Martin Sports Car, Maserati, Lamborghini, Ferrari, Bugatti Cars, Aston Martin Vanquish, <PERSON>, Sweet Cars, Amazing Cars'}, {148: 'Metal working projects - You should not show an illustration whatsoever or show off different examples so kids can cause things themselves. Blacksmith Tools, Lathe Tools, Metal Tools, Wood Lathe, Homemade Lathe, Homemade Tools, Metal Projects, Welding Projects, Engineering Tools'}, {149: 'The <PERSON> with Protective Cloak, by <PERSON> or <PERSON>, c. 1480.'}]
# Raw output is {
#     "140": "The Hardwood Floor Medallion Inlay from COMPASS III",
#     "141": "House available for sale in Sharjah, Al Qadisiyah area",
#     "142": "Strike Up The Band, 1940 - A photo displayed on a wall",
#     "143": "Sea stacks resemble hooks carved from the ocean along the coast of south Westland",
#     "144": "Digitalis purpurea - The Foxglove flowers",
#     "145": "Uyghur vendor at the market in Kashgar, Xinjiang, China",
#     "146": "Magnolia Hotel & Spa",
#     "147": "This extremely rare Aston Martin Vanquish is being paired with a Zagato coupe, sold only as a set. Aston Martin Sports Cars, Maserati, Lamborghini, Ferrari, Bugatti, Sweet Cars, Amazing Cars",
#     "148": "Metalworking projects - Avoid showing any illustrations or examples so that children can create things by themselves. Blacksmith Tools, Lathe Tools, Metal Tools, Wood Lathe, Homemade Lathe, Homemade Tools, Metal Projects, Welding Projects, Engineering Tools",
#     "149": "The figure in a Protective Cloak, by an artist around 1480."
# }
# ...
#     "454": "A girl on a swing under a tree with a boy, created in a paper art style illustration with floral elements in the background",
#     "455": "Dottie the <PERSON> red leather zip-top handbag",
#     "456": "This photo, taken on March 17, 2014, features a Pakistani street child <PERSON> at a football training camp in Karachi. -Photo by AFP",
#     "457": "Wind symbol icon, representing weather and climate, illustrating a windy sign, vector graphics with a linear design on a white backdrop, royalty free illustration",
#     "458": "<PERSON> beams while sitting on a bed in a wedding dress, trying on a shoe with the help of a bridesmaid, while another bridesmaid in a brinjal colored dress is also present.",
#     "459": "Sun shining through clouds with raindrops. Retro style vector weather icons featuring the sun behind clouds and rain drops, royalty free illustration"
# }
# Output dict is  {'450': 'Top Apple Crisp Recipe--Why is it the best? It delivers the same deliciousness as a classic apple crisp recipe while being suitable for nearly everyone. It is gluten free, paleo, dairy free, aligns with the coconut diet, primal SCD, grain free, and GAPS diet. Paleo Apple Crisp, Best Apple Crisp Recipe, Apple Crisp Recipes, Apple Crips, Gluten Free Sweets, Paleo Sweets, Paleo Dessert, Healthy Desserts, Diet Desserts', '451': 'Illustration of a bird perched on a wire, royalty free', '452': "<PERSON> at a Valentine's Day Event, featuring layered hair, celebrities, hair inspirations, bridal hair, <PERSON>, a lady, and various hair styles", '453': '3D illustration of a sparkling red glitter letter <PERSON> with a shiny, sparkly style and classic font, set against a white background with a clipping path', '454': 'A girl on a swing under a tree with a boy, created in a paper art style illustration with floral elements in the background', '455': 'Dottie the <PERSON> red leather zip-top handbag', '456': 'This photo, taken on March 17, 2014, features a Pakistani street child <PERSON> at a football training camp in Karachi. -Photo by AFP', '457': 'Wind symbol icon, representing weather and climate, illustrating a windy sign, vector graphics with a linear design on a white backdrop, royalty free illustration', '458': '<PERSON> beams while sitting on a bed in a wedding dress, trying on a shoe with the help of a bridesmaid, while another bridesmaid in a brinjal colored dress is also present.', '459': 'Sun shining through clouds with raindrops. Retro style vector weather icons featuring the sun behind clouds and rain drops, royalty free illustration'}
# [{460: 'Large cresting wave with mountains in the distance'}, {461: 'The 39 Greatest Constructions of Gothic Architecture in the World'}, {462: 'Allow Yourself To Be Mesmerized By These Girls In Mesh Clothing (46 pics)'}, {463: '<PERSON> showing a coastal town and a bay or harbor'}, {464: 'Baby Sea Turtles Make A ... is listed (or ranked) 4 on the list 11 Baby Animals That Have To Go Through Brutal Gauntlets To Survive'}, {465: "A shelving system in the living room displays books, decor, and the couple's vinyl collection."}, {466: "Love is in the air! <PERSON> to be with <PERSON> on Valentine's Day"}, {467: 'The Spanish <PERSON> horse is a very rare breed and crosses the blood of Andalusian animals of Spain with that of the Percheron of France. <PERSON>, Horse Saddles, Draft Horses, Horse Breeds, Crosses, <PERSON>, Art Reference, Mustang, Spanish'}, {468: "<PERSON> Asks US Congress to 'End Gun Violence' after Scoring a Goal in Major Soccer League"}, {469: '17 geeky nostalgia-infused tattoos to remind you of the simpler times | brain berries'}]
# Raw output is ```json
# {
#     "460": "A massive wave crashing with mountains visible in the background",
#     "461": "The 39 Most Impressive Examples of Gothic Architecture Around the Globe",
#     "462": "Let Yourself Get Captivated By These Girls in Mesh Outfits (46 images)",
#     "463": "A scenic overview of a coastal town and its bay or harbor",
#     "464": "Baby sea turtles rank 4th on the list of 11 baby animals that face harsh challenges to survive",
#     "465": "A bookshelf in the living room showcases books, decorative items, and the couple's vinyl records.",
#     "466": "Romance is in the air! A couple enjoys Valentine's Day together",
#     "467": "The Spanish horse is a rare breed that mixes Andalusian blood with that of the French Percheron.",
#     "468": "A player requests the US Congress to 'End Gun Violence' after scoring a goal in a major soccer league",
#     "469": "17 nerdy tattoos filled with nostalgia to evoke memories of simpler times | brain berries"
# }
# ```
# Output dict is  {'460': 'A massive wave crashing with mountains visible in the background', '461': 'The 39 Most Impressive Examples of Gothic Architecture Around the Globe', '462': 'Let Yourself Get Captivated By These Girls in Mesh Outfits (46 images)', '463': 'A scenic overview of a coastal town and its bay or harbor', '464': 'Baby sea turtles rank 4th on the list of 11 baby animals that face harsh challenges to survive', '465': "A bookshelf in the living room showcases books, decorative items, and the couple's vinyl records.", '466': "Romance is in the air! A couple enjoys Valentine's Day together", '467': 'The Spanish horse is a rare breed that mixes Andalusian blood with that of the French Percheron.', '468': "A player requests the US Congress to 'End Gun Violence' after scoring a goal in a major soccer league", '469': '17 nerdy tattoos filled with nostalgia to evoke memories of simpler times | brain berries'}
# [{470: 'Giuseppe Garibaldi The Sword of Italian Unification (The Fighter)'}, {471: 'Actor <PERSON> and film director <PERSON> on the set of the film The Conversation,--Photo displayed on a wall'}, {472: 'During the cold winter, some bats migrate to a warmer area.'}, {473: 'Need some comfy, cozy outfit ideas for lounging indoors with the fam? Sharing 4 looks (on MAJOR sal Winter Vest Outfits, Vest Outfits For Women, Winter Fashion Outfits, Fall Outfits, Casual Outfits, Autumn Fashion, Cute Outfits, Clothes For Women, White Vest Outfit'}, {474: 'Animation cute witch in a hat on a background of the night sky and the moon. Vector illustration Stock Illustration'}, {475: 'Snowman face magnet we made for the grandparents Winter Crafts For Toddlers, Fun Crafts For Kids, Craft Activities For Kids, Preschool Christmas Crafts, Christmas Arts And Crafts, Preschool Themes, Preschool Crafts, <PERSON>, Sneezy The Snowman'}, {476: '<PERSON> with a <PERSON> in Need of Abuse | by The Last Tuesday Society'}, {477: 'Photo of a Gatlinburg Cabin named Pool House - This is the eleventh photo in the set.'}, {478: 'Step 4 - The rust develops overnight'}, {479: 'Knowing how to deliver effective PowerPoint presentations is a key to business success.'}]
# Raw output is ```json
# {
#     "470": "Giuseppe Garibaldi, the Sword of Italian Unity (The Warrior)",
#     "471": "Actor and director on the film set of The Conversation, --Image featured on a wall",
#     "472": "In the chilly winter, some bats travel to warmer regions.",
#     "473": "Looking for comfy outfit ideas to relax indoors with family? Here are 4 cozy looks (including trendy winter vests, outfits for women, and fall fashion).",
#     "474": "A charming witch in a hat against a starry night sky and moon. Vector art illustration.",
#     "475": "Magnet featuring a snowman face that we created for the grandparents. Winter crafting ideas for toddlers and kids.",
#     "476": "Individual with a in Need of Abuse | by The Last Tuesday Society",
#     "477": "Image of a Gatlinburg cabin called Pool House - This is the eleventh picture in the collection.",
#     "478": "Step 4 - The rust forms by morning.",
#     "479": "Mastering effective PowerPoint presentations is essential for business success."
# }
# ```
# Output dict is  {'470': 'Giuseppe Garibaldi, the Sword of Italian Unity (The Warrior)', '471': 'Actor and director on the film set of The Conversation, --Image featured on a wall', '472': 'In the chilly winter, some bats travel to warmer regions.', '473': 'Looking for comfy outfit ideas to relax indoors with family? Here are 4 cozy looks (including trendy winter vests, outfits for women, and fall fashion).', '474': 'A charming witch in a hat against a starry night sky and moon. Vector art illustration.', '475': 'Magnet featuring a snowman face that we created for the grandparents. Winter crafting ideas for toddlers and kids.', '476': 'Individual with a in Need of Abuse | by The Last Tuesday Society', '477': 'Image of a Gatlinburg cabin called Pool House - This is the eleventh picture in the collection.', '478': 'Step 4 - The rust forms by morning.', '479': 'Mastering effective PowerPoint presentations is essential for business success.'}
# [{480: 'Wholesale boat neck mother bride dresses for sale - Group buy 2016 Gold Lace Mermaid Gown Mother of the Bride Dress Long Sleeves Fitted Boat Neck Sweep Train Formal Prom Evening Dress'}, {481: 'Boat floating on the ocean Royalty Free Stock Vectors'}, {482: 'Like All Animals, We Need Stress. Just Not Too Much'}, {483: 'Wynn Las Vegas: From the Desk looking at the super comfy bed and entry way'}, {484: 'The Anchorage Port Stephens Wedding Photography'}, {485: 'Watercolor drawing with the text coronavirus, model of the virus, the problem of the spread of coronavirus. The pandemic alert. stock photography'}, {486: '<PERSON> - Logo -- <PERSON> the Maker'}, {487: 'The <PERSON> by Daisy Church Japanese Mythology, Japanese Folklore, Japanese Art, Art And Illustration, Daisy Drawing, The Decemberists, Design Art, Art Pieces, Original Art'}, {488: 'A dying sea bird, its feathers being covered with oil.'}, {489: 'Drinking any more than 9 small glasses (125ml) of bubbles in a week will put you over the low risk drinking guidelines.'}]
# Raw output is {
#     "480": "Mother of the bride dresses available at wholesale - Group purchase 2016 Gold Lace Mermaid Gown with Long Sleeves and Fitted Boat Neck for formal prom or evening events.",
#     "481": "Boat drifting on the sea - Royalty Free Stock Vectors.",
#     "482": "Like all living beings, we require some stress, just not an excess of it.",
#     "483": "Wynn Las Vegas: A view from the desk towards the cozy bed and entrance.",
#     "484": "Wedding photography at Anchorage Port Stephens.",
#     "485": "Watercolor illustration featuring coronavirus text, virus model, and the issue of its spread. A pandemic alert in stock photography.",
#     "486": "<PERSON> - Brand logo -- <PERSON> the creator.",
#     "487": "The <PERSON> by Daisy Church showcases Japanese mythology, folklore, art, illustration, Daisy's drawing style, The Decemberists, design art, and original pieces.",
#     "488": "An oil-covered sea bird struggling to survive.",
#     "489": "Consuming more than 9 small glasses (125ml) of sparkling drinks weekly will exceed the low-risk drinking recommendations."
# }
# Output dict is  {'480': 'Mother of the bride dresses available at wholesale - Group purchase 2016 Gold Lace Mermaid Gown with Long Sleeves and Fitted Boat Neck for formal prom or evening events.', '481': 'Boat drifting on the sea - Royalty Free Stock Vectors.', '482': 'Like all living beings, we require some stress, just not an excess of it.', '483': 'Wynn Las Vegas: A view from the desk towards the cozy bed and entrance.', '484': 'Wedding photography at Anchorage Port Stephens.', '485': 'Watercolor illustration featuring coronavirus text, virus model, and the issue of its spread. A pandemic alert in stock photography.', '486': '<PERSON> - Brand logo -- <PERSON> the creator.', '487': "The <PERSON> by Daisy Church showcases Japanese mythology, folklore, art, illustration, Daisy's drawing style, The Decemberists, design art, and original pieces.", '488': 'An oil-covered sea bird struggling to survive.', '489': 'Consuming more than 9 small glasses (125ml) of sparkling drinks weekly will exceed the low-risk drinking recommendations.'}
# [{490: 'Strip finger guard finger metacarpal fracture fixation sprain nursing care with a protective sleeve sheath brace finger splint sets'}, {491: 'Landscape Photography Basics: Determine the focus on the photo. While most lands... Landscape Photography Basics: Determine the focus on the Photography Basics, Amazing Photography, Nature Photography, Photography Ideas, Depth Of Field Photography, Photography Backdrop Stand, Halloween Photography, Passion Photography, Beautiful Landscape Photography'}, {492: 'Happy family, mother, father, two children, grandparents. Festive clothing, a good mood. Characters for cards. Vector cartoon illustration cartoon, beautiful stock illustration'}, {493: 'Plastic shuttlecock of badminton put on the green net of badminton racket. It is a cork to which feathers are attached to form a cone shape, or a similar stock photos'}, {494: "The extended body on the this fly creates a mouthful for most panfish. Expect a lot of hits that don't result in hookups. These are usually smaller fish determined to eat the fly, but simply cant fit the entire thing in their tiny mouths!."}, {495: 'Vector illustration of flowers in the shape of the moon. Black and white moon illustration isolated on white background'}, {496: "Winter snow storm in Boston's Public Garden ... on a day when NO snow was predicted!"}, {497: 'Close-up of business plan with people working in the background Free Photo'}, {498: 'All smiles, <PERSON> poses for the lens of photographer <PERSON>.'}]
# Raw output is {
#     "490": "Finger guard for metacarpal fracture management and sprain care, including a protective sleeve, sheath, brace, and splint sets.",
#     "491": "Basic tips for landscape photography: Focus determination is key. Explore amazing photography concepts such as depth of field and photo backdrop ideas.",
#     "492": "A joyful family consisting of parents, two kids, and grandparents, dressed festively and in high spirits, illustrated in a vector cartoon style.",
#     "493": "A plastic badminton shuttlecock resting on a green racket net, featuring a cork with attached feathers forming a cone shape.",
#     "494": "This fly's extended body attracts numerous panfish, leading to many bites without connections, often from smaller fish unable to consume the entire fly.",
#     "495": "Illustration of flowers shaped like the moon in vector format, presented in black and white against a white background.",
#     "496": "A winter snowstorm unexpectedly hits Boston's Public Garden on a day when no snow was forecasted!",
#     "497": "Close-up of a business plan being discussed with individuals working in the background.",
#     "498": "All smiles as the subject poses for the camera captured by the photographer."
# }
# Output dict is  {'490': 'Finger guard for metacarpal fracture management and sprain care, including a protective sleeve, sheath, brace, and splint sets.', '491': 'Basic tips for landscape photography: Focus determination is key. Explore amazing photography concepts such as depth of field and photo backdrop ideas.', '492': 'A joyful family consisting of parents, two kids, and grandparents, dressed festively and in high spirits, illustrated in a vector cartoon style.', '493': 'A plastic badminton shuttlecock resting on a green racket net, featuring a cork with attached feathers forming a cone shape.', '494': "This fly's extended body attracts numerous panfish, leading to many bites without connections, often from smaller fish unable to consume the entire fly.", '495': 'Illustration of flowers shaped like the moon in vector format, presented in black and white against a white background.', '496': "A winter snowstorm unexpectedly hits Boston's Public Garden on a day when no snow was forecasted!", '497': 'Close-up of a business plan being discussed with individuals working in the background.', '498': 'All smiles as the subject poses for the camera captured by the photographer.'}

# %% [markdown]
# ## Generate Long Captions

# %%
LONG_CAPTIONS_FILE_PATH = "./long_generated_captions.csv"
initialize_csv(LONG_CAPTIONS_FILE_PATH)

generate_captions(df, "vlm_model", LONG_CAPTIONS_FILE_PATH, 50)

# %%
folder_path = "./images"

# use regex to extract the num pattern
number_pattern = re.compile(r'(\d+)')

# get every file
files = [f for f in os.listdir(folder_path) if f.lower().endswith(".jpg")]

# extract and sort numbers, we need to sort so that we save correct images to correct numbers
def extract_number(f):
    match = number_pattern.search(f)
    return int(match.group())

sorted_files = sorted(files, key=extract_number)

# Rename files sequentially
for idx, old_name in enumerate(sorted_files, start=1):
    new_name = f"img_{idx}.jpg"
    
    old_path = os.path.join(folder_path, old_name)
    new_path = os.path.join(folder_path, new_name)
    
    print(f"Renaming {old_name} to {new_name}")
    os.rename(old_path, new_path)

# %%
df = pd.read_csv("./long_generated_captions.csv")
# Out:
#       id                                            img_url  \
# 0      1  https://thumbs.dreamstime.com/b/car-riding-wet...
# 1      2  https://images.pexels.com/photos/770224/pexels...
# 2      3  https://filmfare.wwmindia.com/content/2017/jul...
# 3      4  https://southernersays.com/wp-content/uploads/...
# 4      5  https://i.pinimg.com/originals/9a/f5/a6/9af5a6...
# ..   ...                                                ...
# 494  594  https://images.squarespace-cdn.com/content/v1/...
# 495  595  https://image.shutterstock.com/z/stock-vector-...
# 496  596  https://www.boston-discovery-guide.com/image-f...
# 497  598  https://image.freepik.com/free-photo/close-up-...
# 498  599  https://www.thefashionisto.com/wp-content/uplo...
#
#                                       original_caption  \
# 0     This image displays:\n\nA black car driving t...
# 1     This image displays: A large rusty pipe with ...
# 2     This image displays: three pictures of Katrin...
# 3     This image displays:\nA photograph of a whale...
# 4     This image displays:\n\nText that reads "20% ...
# ..                                                 ...
# 494   This image displays: A close-up photograph of...
# 495   This image displays:\n\nA black crescent moon...
# 496   This image displays: Two women walking away f...
# 497   This image displays:\n\nIn the foreground of ...
# 498   This image displays:\n\nThis image displays a...
#
#                                    paraphrased_caption
# 0    This image features a black car splashing thro...
# 1    This image presents a large rusty pipe with a ...
# 2    This image shows three photos of a woman. The ...
# 3    This image captures a whale's tail fin rising ...
# 4    This image consists of text that says '20% Duo...
# ..                                                 ...
# 494  This image presents a close-up shot of a blueg...
# 495  This image consists of a black crescent moon a...
# 496  This image captures two women walking away fro...
# 497  This image shows a desk in the foreground with...
# 498  In this image, a man is seen seated in a dark ...
#
# [499 rows x 4 columns]

# %%
df["id"] = range(1, 500)

# %%
df["id"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 494    495
# 495    496
# 496    497
# 497    498
# 498    499
# Name: id, Length: 499, dtype: int64

# %%
df.to_csv("./long_generated_captions.csv", index=False)

# %%
df_s_captions = pd.read_csv("./short_generated_captions.csv")

# %%
df_s_captions["id"] = df_s_captions["id"] + 1

# %%
df_s_captions.to_csv("./short_generated_captions.csv", index=False)
